# %%
"""
Memory optimize garna -> use smaller data types.
"""

import numpy as np
import time

start = time.time()

X = np.random.random(10000000)
for i in range(X.shape[0]):
    X[i] = X[i] + 2

end = time.time()

print(X[:10])

print(f"The time taken is {end-start} seconds")
# Out:
# [2.69877269 2.85725171 2.15702802 2.25880478 2.29375123 2.7701523
#  2.18754552 2.98136913 2.97960189 2.46862855]
# The time taken is 1.414081335067749 seconds

# %%
import numpy as np
import time

start = time.time()

X = np.random.random(10000000)

X = X + 2

end = time.time()

print(X[:10])

print(f"The time taken is {end-start} seconds")
# Out:
# [2.92997076 2.45565131 2.9674271  2.27506356 2.92360078 2.62522972
#  2.61569433 2.47143687 2.50068366 2.60746572]
# The time taken is 0.061276912689208984 seconds
