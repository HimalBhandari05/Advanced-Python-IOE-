# %%
"""
Create a table for Books with fields: title, author, year.
Insert 3 books and query by author.
Update a book year.
Delete a book.
"""

from sqlalchemy import create_engine


engine = create_engine("sqlite:///newone.db", echo=True)

# %%
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String

Base = declarative_base()


class Books(Base):
    __tablename__ = "Books"
    id = Column(Integer, primary_key=True)
    title = Column(String)
    author = Column(String)
    year = Column(Integer)
    
Base.metadata.create_all(engine)
# Out:
# 2026-02-17 16:04:20,255 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-17 16:04:20,258 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Books")
# 2026-02-17 16:04:20,259 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-17 16:04:20,262 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Books")
# 2026-02-17 16:04:20,263 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-17 16:04:20,267 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Books" (
# 	id INTEGER NOT NULL,
# 	title VARCHAR,
# 	author VARCHAR,
# 	year INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-02-17 16:04:20,268 INFO sqlalchemy.engine.Engine [no key 0.00124s] ()
# 2026-02-17 16:04:20,278 INFO sqlalchemy.engine.Engine COMMIT
# /tmp/ipykernel_12507/4096246014.py:4: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
from sqlalchemy.orm import sessionmaker


Session = sessionmaker(bind=engine)
session = Session()

# %%
book1 = Books(title="Python", author="Himal Bhandari", year=2020)
book2 = Books(title="Computer", author="Sajina Bhandari", year=2002)
book3 = Books(title="Database", author="Himjin Bhandari", year=2025)

session.add(book1)
session.add(book2)
session.add(book3)

session.commit()
# Out:
# 2026-02-17 16:14:46,059 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-17 16:14:46,061 INFO sqlalchemy.engine.Engine INSERT INTO "Books" (title, author, year) VALUES (?, ?, ?) RETURNING id
# 2026-02-17 16:14:46,062 INFO sqlalchemy.engine.Engine [cached since 266.1s ago (insertmanyvalues) 1/3 (ordered; batch not supported)] ('Python', 'Himal Bhandari', 2020)
# 2026-02-17 16:14:46,064 INFO sqlalchemy.engine.Engine INSERT INTO "Books" (title, author, year) VALUES (?, ?, ?) RETURNING id
# 2026-02-17 16:14:46,066 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/3 (ordered; batch not supported)] ('Computer', 'Sajina Bhandari', 2002)
# 2026-02-17 16:14:46,067 INFO sqlalchemy.engine.Engine INSERT INTO "Books" (title, author, year) VALUES (?, ?, ?) RETURNING id
# 2026-02-17 16:14:46,068 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/3 (ordered; batch not supported)] ('Database', 'Himjin Bhandari', 2025)
# 2026-02-17 16:14:46,069 INFO sqlalchemy.engine.Engine COMMIT

# %%
book = session.query(Books).filter_by(title="Python").first()
book.title = "Computer Network"
session.commit()
# Out:
# 2026-02-17 16:14:46,866 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-17 16:14:46,868 INFO sqlalchemy.engine.Engine SELECT "Books".id AS "Books_id", "Books".title AS "Books_title", "Books".author AS "Books_author", "Books".year AS "Books_year"
# FROM "Books"
# WHERE "Books".title = ?
#  LIMIT ? OFFSET ?
# 2026-02-17 16:14:46,869 INFO sqlalchemy.engine.Engine [cached since 99.26s ago] ('Python', 1, 0)
# 2026-02-17 16:14:46,873 INFO sqlalchemy.engine.Engine UPDATE "Books" SET title=? WHERE "Books".id = ?
# 2026-02-17 16:14:46,874 INFO sqlalchemy.engine.Engine [cached since 99.26s ago] ('Computer Network', 4)
# 2026-02-17 16:14:46,876 INFO sqlalchemy.engine.Engine COMMIT

# %%
book_delete = session.query(Books).filter_by(title="Computer").first()
print(book_delete)

session.delete(book_delete)
session.commit()
# Out:
# 2026-02-17 16:14:47,217 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-17 16:14:47,219 INFO sqlalchemy.engine.Engine SELECT "Books".id AS "Books_id", "Books".title AS "Books_title", "Books".author AS "Books_author", "Books".year AS "Books_year"
# FROM "Books"
# WHERE "Books".title = ?
#  LIMIT ? OFFSET ?
# 2026-02-17 16:14:47,220 INFO sqlalchemy.engine.Engine [cached since 99.61s ago] ('Computer', 1, 0)
# ...
# 2026-02-17 16:14:47,224 INFO sqlalchemy.engine.Engine DELETE FROM "Books" WHERE "Books".id = ?
# 2026-02-17 16:14:47,225 INFO sqlalchemy.engine.Engine [cached since 14.25s ago] (5,)
# 2026-02-17 16:14:47,227 INFO sqlalchemy.engine.Engine COMMIT

# %%
updateYear = session.query(Books).filter_by(year=2020).first()
updateYear.year = 2026
session.commit()
# Out:
# 2026-02-17 16:15:29,886 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-17 16:15:29,890 INFO sqlalchemy.engine.Engine SELECT "Books".id AS "Books_id", "Books".title AS "Books_title", "Books".author AS "Books_author", "Books".year AS "Books_year"
# FROM "Books"
# WHERE "Books".year = ?
#  LIMIT ? OFFSET ?
# 2026-02-17 16:15:29,891 INFO sqlalchemy.engine.Engine [generated in 0.00136s] (2020, 1, 0)
# 2026-02-17 16:15:29,895 INFO sqlalchemy.engine.Engine UPDATE "Books" SET year=? WHERE "Books".id = ?
# 2026-02-17 16:15:29,896 INFO sqlalchemy.engine.Engine [generated in 0.00134s] (2026, 1)
# 2026-02-17 16:15:29,899 INFO sqlalchemy.engine.Engine COMMIT
